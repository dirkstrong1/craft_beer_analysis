# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_beers = pd.read_csv("raw_data/beers.csv")
df_breweries = pd.read_csv("raw_data/breweries.csv")

# %% [markdown]
# # Explore Data

# %%
df_beers.head()

# %%
df_breweries.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
df_breweries_clean = df_breweries.rename(columns={'Unnamed: 0': "brewery_id"})

# %%
df_breweries_clean.set_index('brewery_id')
# Out:
#                                            name           city state
# brewery_id
# 0                            NorthGate Brewing     Minneapolis    MN
# 1                     Against the Grain Brewery     Louisville    KY
# 2                      Jack's Abby Craft Lagers     Framingham    MA
# 3                     Mike Hess Brewing Company      San Diego    CA
# 4                       Fort Point Beer Company  San Francisco    CA
# 5                         COAST Brewing Company     Charleston    SC
# 6                  Great Divide Brewing Company         Denver    CO
# 7                              Tapistry Brewing       Bridgman    MI
# 8                              Big Lake Brewing        Holland    MI
# 9                    The Mitten Brewing Company   Grand Rapids    MI
# 10                               Brewery Vivant   Grand Rapids    MI
# 11                             Petoskey Brewing       Petoskey    MI
# ...

# %%
df_breweries_clean.drop('Unnamed: 0', axis=1)
# Out:
#                                               city state
# name
# NorthGate Brewing                      Minneapolis    MN
# Against the Grain Brewery               Louisville    KY
# Jack's Abby Craft Lagers                Framingham    MA
# Mike Hess Brewing Company                San Diego    CA
# Fort Point Beer Company              San Francisco    CA
# COAST Brewing Company                   Charleston    SC
# Great Divide Brewing Company                Denver    CO
# Tapistry Brewing                          Bridgman    MI
# Big Lake Brewing                           Holland    MI
# The Mitten Brewing Company            Grand Rapids    MI
# Brewery Vivant                        Grand Rapids    MI
# Petoskey Brewing                          Petoskey    MI
# Blackrocks Brewery                       Marquette    MI
# Perrin Brewing Company               Comstock Park    MI
# Witch's Hat Brewing Company             South Lyon    MI
# ...

# %%
df_beers_clean = df_beers.drop("Unnamed: 0", axis=1)

# %%
df_beers_clean.set_index("id")
# Out:
#         abv    ibu                                         name  \
# id
# 1436  0.050    NaN                                     Pub Beer
# 2265  0.066    NaN                                  Devil's Cup
# 2264  0.071    NaN                          Rise of the Phoenix
# 2263  0.090    NaN                                     Sinister
# 2262  0.075    NaN                                Sex and Candy
# 2261  0.077    NaN                                 Black Exodus
# 2260  0.045    NaN                          Lake Street Express
# 2259  0.065    NaN                                      Foreman
# 2258  0.055    NaN                                         Jade
# 2131  0.086    NaN                                 Cone Crusher
# 2099  0.072    NaN                            Sophomoric Saison
# 2098  0.073    NaN                        Regional Ring Of Fire
# 2097  0.069    NaN                                   Garce Selé
# 1980  0.085    NaN                              Troll Destroyer
# ...

# %%
df_beers_clean.isnull().sum()
# Out:
# abv             62
# ibu           1005
# id               0
# name             0
# style            5
# brewery_id       0
# ounces           0
# dtype: int64
